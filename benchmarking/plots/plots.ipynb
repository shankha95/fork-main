# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
def custom_y_label_formatter(value, pos):
    return f'{round(value)}%'

# %%
fig, ax = plt.subplots()
ax.grid(True)
boxes = [
    {
        'label' : "Single user\nSingle cluster",
        'whislo': 2.232,
        'q1'    : 2.699,
        'med'   : 2.816,
        'q3'    : 2.982,
        'whishi': 3.382,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster",
        'whislo': 3.701,
        'q1'    : 4.896,
        'med'   : 5.079,
        'q3'    : 5.288,
        'whishi': 5.725,
        'fliers': []       # Outliers
    },
    {
        'label' : "Multi user\nSingle cluster",
        'whislo': 2.633,
        'q1'    : 3.520,
        'med'   : 4.065,
        'q3'    : 4.756,
        'whishi': 5.481,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster",
        'whislo': 3.908,
        'q1'    : 5.028,
        'med'   : 5.771,
        'q3'    : 6.568,
        'whishi': 7.712,
        'fliers': []        # Outliers
    },
]

b = ax.bxp(boxes, showfliers=False, patch_artist=True)
# ax.set_xticklabels([i['label'] for i in boxes], fontsize=10, fontweight='bold')

ax.set_ylabel("Milliseconds", fontsize=10, fontweight='bold')

for tick in ax.get_xticklabels():
    tick.set_fontsize(10)
    tick.set_fontweight('bold')

for tick in ax.get_yticklabels():
    tick.set_fontsize(10)
    tick.set_fontweight('bold')

# ax.title.set_text("Light workload")

# b['boxes'][0].set(color='red')
# b['whiskers'][0].set(color='red')
# b['whiskers'][1].set(color='red')
# b['caps'][0].set(color='red')
# b['caps'][1].set(color='red')
# b['medians'][0].set(color='red')

# b['boxes'][1].set(color='red')
# b['whiskers'][2].set(color='red')
# b['whiskers'][3].set(color='red')
# b['caps'][2].set(color='red')
# b['caps'][3].set(color='red')
# b['medians'][1].set(color='red')

# b['boxes'][2].set(color='green')
# b['whiskers'][4].set(color='green')
# b['whiskers'][5].set(color='green')
# b['caps'][4].set(color='green')
# b['caps'][5].set(color='green')
# b['medians'][2].set(color='green')

# b['boxes'][3].set(color='green')
# b['whiskers'][6].set(color='green')
# b['whiskers'][7].set(color='green')
# b['caps'][6].set(color='green')
# b['caps'][7].set(color='green')
# b['medians'][3].set(color='green')

for box in b['boxes']:
    box.set_facecolor('lightgrey')

# plt.savefig("plots/latencies_light_workload.png")
plt.savefig("plots/latencies_light_workload.pdf", format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(True)
boxes = [
    {
        'label' : "Single user\nSingle cluster",
        'whislo': 21.654,
        'q1'    : 23.732,
        'med'   : 24.529,
        'q3'    : 25.757,
        'whishi': 27.932,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster",
        'whislo': 24.571,
        'q1'    : 27.185,
        'med'   : 27.928,
        'q3'    : 28.904,
        'whishi': 31.086,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nSingle cluster",
        'whislo': 21.434,
        'q1'    : 22.422,
        'med'   : 26.496,
        'q3'    : 33.109,
        'whishi': 39.508,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster",
        'whislo': 23.832,
        'q1'    : 25.477,
        'med'   : 28.988,
        'q3'    : 35.528,
        'whishi': 42.821,
        'fliers': []        # Outliers
    },
]

b = ax.bxp(boxes, showfliers=False, patch_artist=True)
ax.set_xticklabels([i['label'] for i in boxes], fontsize=10, fontweight='bold')

ax.set_ylabel("Milliseconds", fontsize=10, fontweight='bold')
for tick in ax.get_yticklabels():
    tick.set_fontsize(10)
    tick.set_fontweight('bold')


# b['boxes'][0].set(color='red')
# b['whiskers'][0].set(color='red')
# b['whiskers'][1].set(color='red')
# b['caps'][0].set(color='red')
# b['caps'][1].set(color='red')
# b['medians'][0].set(color='red')

# b['boxes'][1].set(color='red')
# b['whiskers'][2].set(color='red')
# b['whiskers'][3].set(color='red')
# b['caps'][2].set(color='red')
# b['caps'][3].set(color='red')
# b['medians'][1].set(color='red')

# b['boxes'][2].set(color='green')
# b['whiskers'][4].set(color='green')
# b['whiskers'][5].set(color='green')
# b['caps'][4].set(color='green')
# b['caps'][5].set(color='green')
# b['medians'][2].set(color='green')

# b['boxes'][3].set(color='green')
# b['whiskers'][6].set(color='green')
# b['whiskers'][7].set(color='green')
# b['caps'][6].set(color='green')
# b['caps'][7].set(color='green')
# b['medians'][3].set(color='green')

for box in b['boxes']:
    box.set_facecolor('lightgrey')


# plt.savefig("plots/latencies_heavy_workload.png")
plt.savefig("plots/latencies_heavy_workload.pdf", format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(True)
boxes = [
    {
        'label' : "Single user\nSingle cluster\nProxy + Service",
        'whislo': 0.759,
        'q1'    : 0.933,
        'med'   : 1.133,
        'q3'    : 1.423,
        'whishi': 1.807,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster\nProxy",
        'whislo': 2.282,
        'q1'    : 2.508,
        'med'   : 2.608,
        'q3'    : 2.770,
        'whishi': 3.119,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster\nService",
        'whislo': 0.317,
        'q1'    : 0.445,
        'med'   : 0.653,
        'q3'    : 0.833,
        'whishi': 1.204,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nSingle cluster\nProxy + Service",
        'whislo': 1.757,
        'q1'    : 2.493,
        'med'   : 2.723,
        'q3'    : 3.053,
        'whishi': 3.345,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster\nProxy",
        'whislo': 6.966,
        'q1'    : 7.735,
        'med'   : 8.003,
        'q3'    : 8.165,
        'whishi': 8.514,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster\nService",
        'whislo': 0.437,
        'q1'    : 0.693,
        'med'   : 0.933,
        'q3'    : 1.075,
        'whishi': 1.622,
        'fliers': []        # Outliers
    },
]

b = ax.bxp(boxes, showfliers=False, patch_artist=True)
ax.set_xticklabels([i['label'] for i in boxes], fontsize=12, fontweight='bold')

ax.set_ylabel("Increase in Percentage (CPU Load - CPU Idle)", fontsize=12, fontweight='bold')
ax.yaxis.set_major_formatter(FuncFormatter(custom_y_label_formatter))

for tick in ax.get_yticklabels():
    tick.set_fontsize(12)
    tick.set_fontweight('bold')


# b['boxes'][0].set(color='darkred')
# b['whiskers'][0].set(color='darkred')
# b['whiskers'][1].set(color='darkred')
# b['caps'][0].set(color='darkred')
# b['caps'][1].set(color='darkred')
# b['medians'][0].set(color='darkred')

# b['boxes'][1].set(color='red')
# b['whiskers'][2].set(color='red')
# b['whiskers'][3].set(color='red')
# b['caps'][2].set(color='red')
# b['caps'][3].set(color='red')
# b['medians'][1].set(color='red')

# b['boxes'][2].set(color='red')
# b['whiskers'][4].set(color='red')
# b['whiskers'][5].set(color='red')
# b['caps'][4].set(color='red')
# b['caps'][5].set(color='red')
# b['medians'][2].set(color='red')

# b['boxes'][3].set(color='darkblue')
# b['whiskers'][6].set(color='darkblue')
# b['whiskers'][7].set(color='darkblue')
# b['caps'][6].set(color='darkblue')
# b['caps'][7].set(color='darkblue')
# b['medians'][3].set(color='darkblue')

# b['boxes'][4].set(color='blue')
# b['whiskers'][8].set(color='blue')
# b['whiskers'][9].set(color='blue')
# b['caps'][8].set(color='blue')
# b['caps'][9].set(color='blue')
# b['medians'][4].set(color='blue')

# b['boxes'][5].set(color='blue')
# b['whiskers'][10].set(color='blue')
# b['whiskers'][11].set(color='blue')
# b['caps'][10].set(color='blue')
# b['caps'][11].set(color='blue')
# b['medians'][5].set(color='blue')

for box in b['boxes']:
    box.set_facecolor('lightgrey')

# plt.savefig("plots/cpu_light_workload.png")
plt.savefig("plots/cpu_light_workload.pdf", format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(True)
boxes = [
    {
        'label' : "Single user\nSingle cluster\nProxy + Service",
        'whislo': 13.922,
        'q1'    : 15.038,
        'med'   : 15.238,
        'q3'    : 15.293,
        'whishi': 15.742,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster\nProxy",
        'whislo': 1.812,
        'q1'    : 2.358,
        'med'   : 2.458,
        'q3'    : 2.758,
        'whishi': 3.266,
        'fliers': []        # Outliers
    },
    {
        'label' : "Single user\nMulti cluster\nService",
        'whislo': 13.177,
        'q1'    : 13.793,
        'med'   : 13.863,
        'q3'    : 14.118,
        'whishi': 14.572,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nSingle cluster\nProxy + Service",
        'whislo': 41.290,
        'q1'    : 45.675,
        'med'   : 45.953,
        'q3'    : 46.805,
        'whishi': 47.345,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster\nProxy",
        'whislo': 7.238,
        'q1'    : 7.953,
        'med'   : 8.213,
        'q3'    : 8.445,
        'whishi': 8.885,
        'fliers': []        # Outliers
    },
    {
        'label' : "Multi user\nMulti cluster\nService",
        'whislo': 42.618,
        'q1'    : 44.040,
        'med'   : 44.148,
        'q3'    : 44.448,
        'whishi': 45.700,
        'fliers': []        # Outliers
    },
]

b = ax.bxp(boxes, showfliers=False, patch_artist=True)
ax.set_xticklabels([i['label'] for i in boxes], fontsize=12, fontweight='bold')

ax.set_ylabel("Increase in Percentage (CPU Load - CPU Idle)", fontsize=12, fontweight='bold')
ax.yaxis.set_major_formatter(FuncFormatter(custom_y_label_formatter))

for tick in ax.get_yticklabels():
    tick.set_fontsize(12)
    tick.set_fontweight('bold')

# b['boxes'][0].set(color='darkred')
# b['whiskers'][0].set(color='darkred')
# b['whiskers'][1].set(color='darkred')
# b['caps'][0].set(color='darkred')
# b['caps'][1].set(color='darkred')
# b['medians'][0].set(color='darkred')

# b['boxes'][1].set(color='red')
# b['whiskers'][2].set(color='red')
# b['whiskers'][3].set(color='red')
# b['caps'][2].set(color='red')
# b['caps'][3].set(color='red')
# b['medians'][1].set(color='red')

# b['boxes'][2].set(color='red')
# b['whiskers'][4].set(color='red')
# b['whiskers'][5].set(color='red')
# b['caps'][4].set(color='red')
# b['caps'][5].set(color='red')
# b['medians'][2].set(color='red')

# b['boxes'][3].set(color='darkblue')
# b['whiskers'][6].set(color='darkblue')
# b['whiskers'][7].set(color='darkblue')
# b['caps'][6].set(color='darkblue')
# b['caps'][7].set(color='darkblue')
# b['medians'][3].set(color='darkblue')

# b['boxes'][4].set(color='blue')
# b['whiskers'][8].set(color='blue')
# b['whiskers'][9].set(color='blue')
# b['caps'][8].set(color='blue')
# b['caps'][9].set(color='blue')
# b['medians'][4].set(color='blue')

# b['boxes'][5].set(color='blue')
# b['whiskers'][10].set(color='blue')
# b['whiskers'][11].set(color='blue')
# b['caps'][10].set(color='blue')
# b['caps'][11].set(color='blue')
# b['medians'][5].set(color='blue')

for box in b['boxes']:
    box.set_facecolor('lightgrey')
    
# ax.title.set_text("Heavy workload")
# plt.savefig("plots/cpu_heavy_workload.png")
plt.savefig("plots/cpu_heavy_workload.pdf", format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
categories = ['50/10', '100/10', '150/10', '50/30', '100/30', '150/30']
values = [59, 109, 159, 79, 129, 179]

fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(categories, values, zorder=3)

ax.grid(True, zorder=0)

ax.set_xlabel('Total Number of Microservices/Number of Cross-Cluster Chained Microservices',  fontsize=12, fontweight='bold', labelpad=12)
ax.set_ylabel('Number of Operations',  fontsize=12, fontweight='bold')

for tick in ax.get_xticklabels():
    tick.set_fontsize(12)
    tick.set_fontweight('bold')

for tick in ax.get_yticklabels():
    tick.set_fontsize(12)
    tick.set_fontweight('bold')


# plt.savefig("plots/steps_barchart.png")
plt.savefig("plots/steps_barchart.pdf", format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()
